# %%
from IPython.display import HTML, display

cover_page = """
<div style="width: 100%; height: 210px; background-color: #ADD8E6; border-radius: 6px; box-shadow: 0 3px 12px rgba(0,0,0,0.05); display: flex; flex-direction: column; justify-content: center; align-items: center; text-align: center; border: 2px solid #EAE3DA;">
    <div style="font-size: 13px; color: #7DFD7F; margin-bottom: 4px; letter-spacing: 2px;">✦ &nbsp; 🌐 &nbsp; ✦</div>
    <h1 style="margin: 0; font-family: 'Georgia', serif; font-size: 38px; font-weight: normal; color: #2C2A29; letter-spacing: 1.5px;">Web Scraping</h1>
    <div style="width: 80px; height: 1px; background: #A09182; margin: 10px 0;"></div>
    <div style="font-family: 'Brush Script MT', 'Lucida Handwriting', cursive; font-size: 25px; color: #5C554F;">Sonam</div>
</div>
"""
display(HTML(cover_page))
# Out:
# <div style="width: 100%; height: 210px; background-color: #ADD8E6; border-radius: 6px; box-shadow: 0 3px 12px rgba(0,0,0,0.05); display: flex; flex-direction: column; justify-content: center; align-items: center; text-align: center; border: 2px solid #EAE3DA;">
#     <div style="font-size: 13px; color: #7DFD7F; margin-bottom: 4px; letter-spacing: 2px;">✦ &nbsp; 🌐 &nbsp; ✦</div>
#     <h1 style="margin: 0; font-family: 'Georgia', serif; font-size: 38px; font-weight: normal; color: #2C2A29; letter-spacing: 1.5px;">Web Scraping</h1>
#     <div style="width: 80px; height: 1px; background: #A09182; margin: 10px 0;"></div>
#     <div style="font-family: 'Brush Script MT', 'Lucida Handwriting', cursive; font-size: 25px; color: #5C554F;">Sonam</div>
# </div>

# %% [markdown]
# <div style="
#     background: #FADAA4;
#     color: #AD597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     Website Name :Quotes To Scrape
#
# </div>

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 1 : Sending HTTP Request 🌐
#
# </div>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://quotes.toscrape.com" 
response= requests.get(url )
response.status_code
# Out:
# 200

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 2 : Extract html content 🌐
#
# </div>

# %%
html_code = response.text
#html_code

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 3 : parsing the HTML 🌐
#
# </div>

# %%
 soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 4 : Extracting Data 🌐
#
# </div>

# %%
quotes = soup.find_all("div", class_="quote")

    for quote in quotes:
        text = quote.find("span", class_="text").get_text(strip=True)
        author = quote.find("small", class_="author").get_text(strip=True)

        tags = [
            tag.get_text(strip=True)
            for tag in quote.find_all("a", class_="tag")
        ]

        quotes_data.append({
            "Quote": text,
            "Author": author,
            "Tags": ", ".join(tags)
        })

      next_button = soup.find("li", class_="next")

      if next_button:
        next_page = next_button.find("a")["href"]
        url = base_url + next_page
      else:
          url = None
# Out:
#   File <string>:18
#     next_button = soup.find("li", class_="next")
#                                                 ^
# IndentationError: unindent does not match any outer indentation level

# %%
df = pd.DataFrame(quotes_data)

df.head()

# %%
<div style="
    background: #FADADD;
    color: #6D597A;
    padding: 12px;
    border-radius: 10px;
    text-align: center;
    font-size: 24px;
    font-weight: bold;
    border: 2px solid #E8C7D1;">
    
    🌐 Step 5 : Storing Data 🌐
    
</div>

# %%
df.to_csv("quotes_to_scrape.csv", index=False)

print("CSV saved successfully!")

# %%
<div style="
    background: #FADADD;
    color: #6D597A;
    padding: 12px;
    border-radius: 10px;
    text-align: center;
    font-size: 24px;
    font-weight: bold;
    border: 2px solid #E8C7D1;">
    
    🌐 Thank You 🌐
    
</div>
