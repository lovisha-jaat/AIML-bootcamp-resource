# %% [markdown]
# ![ChatGPT Image Jul 3, 2026, 12_13_55 PM.png](<attachment:ChatGPT Image Jul 3, 2026, 12_13_55 PM.png>)

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     Website Name : Amazon
#
# </div>

# %%
# !pip install selenium pandas webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# %%
options = Options()
options.add_argument("--start-maximized")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

url = "https://www.amazon.in/s?k=laptop"
driver.get(url)

time.sleep(5)

# %%
products = driver.find_elements(By.XPATH, "//div[@data-component-type='s-search-result']")

print("Total products found:", len(products))

data = []

for product in products:
    
    try:
        title = product.find_element(By.XPATH, ".//h2//span").text
    except:
        title = "N/A"

    try:
        price = product.find_element(By.XPATH, ".//span[@class='a-price-whole']").text
        price = "₹" + price
    except:
        price = "N/A"

    try:
        rating = product.find_element(By.XPATH, ".//span[contains(@class,'a-icon-alt')]").get_attribute("innerHTML")
    except:
        rating = "N/A"

    try:
        link = product.find_element(By.XPATH, ".//a[@class='a-link-normal s-no-outline']").get_attribute("href")
    except:
        link = "N/A"

    data.append({
        "Title": title,
        "Price": price,
        "Rating": rating,
        "Product Link": link
    })

df = pd.DataFrame(data)

print("Total data rows:", len(df))
df
# Out:
# Total products found: 22
# Total data rows: 22
#                                                 Title      Price  \
# 0   ASUS Zenbook 14 (2026),Smartchoice,Intel Core ...  ₹1,35,990
# 1   HP 15 (i5 14th Gen), Intel Core 5, 16GB RAM (U...    ₹69,990
# 2   HP 15 Smartchoice, 13th Gen Intel Core i3-1315...    ₹48,990
# 3   ASUS Vivobook 15, Smartchoice,Intel Core i5 13...    ₹64,990
# 4   ASUS Vivobook 15, Smartchoice,Intel Core i3 13...    ₹44,990
# 5   Acer Smartchoice Aspire One, Intel Core Celero...    ₹35,990
# 6   Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8...    ₹44,999
# 7   Acer Aspire Lite 12th Gen, Intel Core i5-12450...    ₹53,990
# 8   HP 15 (2026), AMD Athlon Dual Core 7120U - (8 ...    ₹39,909
# 9   HP Professional 15 (2026), Intel (i5 14th Gen)...    ₹55,550
# 10  Acer Aspire 5, Intel Core Ultra 5 125H Process...    ₹76,990
# 11  HP 15 Smartchoice, Intel Core Ultra 5 125H, 12...    ₹74,990
# 12  HP 15, 13th Gen Intel Core i3-1315U Laptop (8G...    ₹53,000
# ...

# %%
df.to_csv("amazon_laptop_data.csv", index=False, encoding="utf-8-sig")
print("CSV saved successfully")
# Out:
# CSV saved successfully

# %%
driver.quit()

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Thank You 🌐
#
# </div>
